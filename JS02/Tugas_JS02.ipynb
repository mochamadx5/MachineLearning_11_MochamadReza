# %% [markdown]
# <a href="https://colab.research.google.com/github/mochamadx5/MachineLearning_11_MochamadReza/blob/main/JS02/Tugas_JS02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
# Load data
df = pd.read_csv('wbc.csv')

# %%
# Pisahkan variabel yang tidak bisa digunakan
df_cleaned = df.drop(columns=['id', 'Unnamed: 32'])

# %%
# Lakukan proses encoding pada kolom "diagnosis"
# Mengubah 'M' (Malignant) dan 'B' (Benign) menjadi angka 1 dan 0
le = LabelEncoder()
df_cleaned['diagnosis'] = le.fit_transform(df_cleaned['diagnosis'])

# %%
# Lakukan standardisasi pada semua kolom numerik
X = df_cleaned.drop(columns=['diagnosis'])
y = df_cleaned['diagnosis']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Gabungkan lagi hasil akhirnya dalam bentuk DataFrame
df_final = pd.DataFrame(X_scaled, columns=X.columns)
df_final.insert(0, 'diagnosis', y)

# %%
df_final.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1     1.097064     -2.073335        1.269934   0.984375
# 1          1     1.829821     -0.353632        1.685955   1.908708
# 2          1     1.579888      0.456187        1.566503   1.558884
# 3          1    -0.768909      0.253732       -0.592687  -0.764464
# 4          1     1.750297     -1.151816        1.776573   1.826229
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0         1.568466          3.283515        2.652874             2.532475
# 1        -0.826962         -0.487072       -0.023846             0.548144
# 2         0.942210          1.052926        1.363478             2.037231
# 3         3.283553          3.402909        1.915897             1.451707
# 4         0.280372          0.539340        1.371011             1.428493
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...
